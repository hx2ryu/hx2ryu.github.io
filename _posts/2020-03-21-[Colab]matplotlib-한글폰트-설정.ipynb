# %% [markdown]
# title: "[Colab]matplotlib 한글폰트 설정하는 방법"
# tag: colab, matplotlib, font
# ---
#
# ## 1. 필요한 라이브러리 추가

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %% [markdown]
# ## 2. 폰트 설치(나눔고딕)

# %%
# 나눔고딕 폰트가 있는지 확인
font_list = fm.findSystemFonts()
font_list

# %%
# font_list에 나눔고딕 폰트가 없을 경우 폰트 설치 (설치되었다면 패스)
# !apt-get install fonts-nanum*

# %%
font_list = fm.findSystemFonts()

# %%
fm.fontManager.findfont('NanumGothic')
